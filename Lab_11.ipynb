# %% [markdown]
# <a href="https://colab.research.google.com/github/Subodh-Shekhar24/APS_LAB/blob/main/Lab_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Travelling Salesman Problem using Dynamic Programming.
# Problem Description:
# Given a set of cities and distances, find the shortest possible route that visits each city once and returns to the starting city.

# %% [markdown]
# #Theory
# TSP uses dynamic programming with bit masking. Store results of visited subsets to reduce repeated work.
#
# ## Algorithm
# 1. Start from source city
# 2. Mark visited cities using bit mask
# 3. Try all unvisited cities
# 4. Choose minimum cost path
# 5. Return to source city

# %%
def tsp(graph):
    n = len(graph)
    dp = [[-1]*(1<<n) for _ in range(n)]

    def visit(city, mask):
        if mask == (1<<n) - 1:
            return graph[city][0]

        if dp[city][mask] != -1:
            return dp[city][mask]

        ans = float('inf')

        for next_city in range(n):
            if mask & (1<<next_city) == 0:
                new_cost = graph[city][next_city] + visit(next_city, mask | (1<<next_city))
                if new_cost < ans:
                    ans = new_cost

        dp[city][mask] = ans
        return ans

    return visit(0, 1)

# %%
graph = [
[0, 10, 15, 20],
[10, 0, 35, 25],
[15, 35, 0, 30],
[20, 25, 30, 0]
]

print("Minimum travelling cost:", tsp(graph))
# Out:
# Minimum travelling cost: 80

# %% [markdown]
# # Exercise
# 1. Print path of cities visited
# 2. Take graph input from user
# 3. Test with different number of cities

# %% [markdown]
# ## Solution to Exercises
#
# 1.  **Print path of cities visited:** The `tsp` function now returns both the minimum cost and the path, which is then printed.
# 2.  **Take graph input from user:** The code uses `input()` to dynamically get the number of cities and the cost matrix from the user.
# 3.  **Test with different number of cities:** The current setup allows the user to input any number of cities. Below is another example with 4 cities.

# %%
def tsp(graph):
    n = len(graph)
    dp = [[-1]*(1<<n) for _ in range(n)]
    parent = [[-1]*(1<<n) for _ in range(n)]

    def visit(city, mask):
        if mask == (1<<n) - 1:
            return graph[city][0]

        if dp[city][mask] != -1:
            return dp[city][mask]

        ans = float('inf')

        for next_city in range(n):
            if mask & (1<<next_city) == 0:
                new_cost = graph[city][next_city] + visit(next_city, mask | (1<<next_city))

                if new_cost < ans:
                    ans = new_cost
                    parent[city][mask] = next_city

        dp[city][mask] = ans
        return ans

    cost = visit(0, 1)


    path = [0]
    mask = 1
    city = 0

    while True:
        next_city = parent[city][mask]
        if next_city == -1:
            break
        path.append(next_city)
        mask |= (1<<next_city)
        city = next_city

    path.append(0)

    return cost, path


n = int(input("Enter number of cities: "))
print("Enter the cost matrix:")

graph = []
for i in range(n):
    row = list(map(int, input().split()))
    graph.append(row)


cost, path = tsp(graph)

print("Minimum travelling cost:", cost)
print("Path:", path)
# Out:
# Enter number of cities: 2
# Enter the cost matrix:
# 1 2
# 3 4
# Minimum travelling cost: 5
# Path: [0, 1, 0]

# %% [markdown]
# ---

# %% [markdown]
# ### Example with 4 Cities

# %%
graph_4_cities = [
    [0, 10, 15, 20],
    [10, 0, 35, 25],
    [15, 35, 0, 30],
    [20, 25, 30, 0]
]

cost_4_cities, path_4_cities = tsp(graph_4_cities)

print("Minimum travelling cost (4 cities):", cost_4_cities)
print("Path (4 cities):", path_4_cities)
# Out:
# Minimum travelling cost (4 cities): 80
# Path (4 cities): [0, 1, 3, 2, 0]

# %% [markdown]
# ## Resources
#
# *   [Travelling Salesman Problem on Wikipedia](https://en.wikipedia.org/wiki/Travelling_salesman_problem)
# *   [Dynamic Programming with Bit Masking for TSP](https://www.geeksforgeeks.org/travelling-salesman-problem-using-dynamic-programming-with-bitmasking/)
