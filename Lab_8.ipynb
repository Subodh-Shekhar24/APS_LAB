# %% [markdown]
# <a href="https://colab.research.google.com/github/Subodh-Shekhar24/APS_LAB/blob/main/Lab_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Minimum Cost Spanning Tree
# Problem Description:
# A spanning tree of a graph can be defined as a graph with minimal set of edges that connect all vertices. A minimum spanning tree of a graph is a spanning tree of the graph with least weight (where the weight is computed by adding the weights of all the edges in the spanning tree). In general, a graph can have multiple minimum spanning trees. The problem is to find a minimum spanning tree of a graph.

# %% [markdown]
# This implementation uses a dictionary to represent the weighted graph, where the vertices are keys, and the values are dictionaries containing their adjacent vertices and their weights.
#
# Please note that this implementation assumes that the input graph is connected and weighted.
#
# First, let's create a simple graph to demonstrate Prim's algorithm:

# %%
graph = {
    "A": {"B": 10, "C": 15, "D": 20},
    "B": {"A": 10, "C": 12},
    "C": {"A": 15, "B": 12, "D": 18},
    "D": {"A": 20, "C": 18},
}

# %% [markdown]
# Now, let's implement Prim's algorithm:

# %%
import heapq

def prim_algorithm(graph):
    min_tree_adj = {vertex: [] for vertex in graph}
    min_weight = 0
    start_vertex = list(graph.keys())[0]

    visited = {start_vertex}

    edges = []


    for neighbor, weight in graph[start_vertex].items():
        heapq.heappush(edges, (weight, start_vertex, neighbor))

    while edges and len(visited) < len(graph):
        weight, u, v = heapq.heappop(edges)

        if v not in visited:
            visited.add(v)
            min_tree_adj[u].append((v, weight))
            min_tree_adj[v].append((u, weight))
            min_weight += weight


            for neighbor_of_v, weight_of_edge in graph[v].items():
                if neighbor_of_v not in visited:
                    heapq.heappush(edges, (weight_of_edge, v, neighbor_of_v))
    return min_tree_adj, min_weight

# %% [markdown]
# Now, let's run the Prim's algorithm on the example graph:
# Keep in mind that this example uses a simple representation of a graph, but for more complex cases, you might want to use a library such as NetworkX to represent and manipulate graphs.

# %%
mst, min_weight = prim_algorithm(graph)
print("Minimum Spanning Tree: ", mst)
print("Minimum Weight: ", min_weight)
# Out:
# Minimum Spanning Tree:  {'A': [('B', 10)], 'B': [('A', 10), ('C', 12)], 'C': [('B', 12), ('D', 18)], 'D': [('C', 18)]}
# Minimum Weight:  40

# %% [markdown]
# Take Differnt example of input graph as discussed in lecture slide and use above code to verify the output

# %%
graph_2 = {
    'A': {'B': 7, 'D': 5},
    'B': {'A': 7, 'C': 8, 'D': 9, 'E': 7},
    'C': {'B': 8, 'E': 5},
    'D': {'A': 5, 'B': 9, 'E': 15, 'F': 6},
    'E': {'B': 7, 'C': 5, 'D': 15, 'F': 8, 'G': 9},
    'F': {'D': 6, 'E': 8, 'G': 11},
    'G': {'E': 9, 'F': 11}
}

# %%
mst_2, min_weight_2 = prim_algorithm(graph_2)
print("Minimum Spanning Tree for graph_2:", mst_2)
print("Minimum Weight for graph_2:", min_weight_2)
# Out:
# Minimum Spanning Tree for graph_2: {'A': [('D', 5), ('B', 7)], 'B': [('A', 7), ('E', 7)], 'C': [('E', 5)], 'D': [('A', 5), ('F', 6)], 'E': [('B', 7), ('C', 5), ('G', 9)], 'F': [('D', 6)], 'G': [('E', 9)]}
# Minimum Weight for graph_2: 39

# %% [markdown]
# Use same apporach for Kruskal's algorithm

# %%
class DSU:
    def __init__(self, vertices):
        self.parent = {v: v for v in vertices}
        self.rank = {v: 0 for v in vertices}

    def find(self, item):
        if self.parent[item] == item:
            return item
        self.parent[item] = self.find(self.parent[item])
        return self.parent[item]

    def union(self, set1, set2):
        root1 = self.find(set1)
        root2 = self.find(set2)
        if root1 != root2:
            if self.rank[root1] < self.rank[root2]:
                self.parent[root1] = root2
            elif self.rank[root1] > self.rank[root2]:
                self.parent[root2] = root1
            else:
                self.parent[root2] = root1
                self.rank[root1] += 1
            return True
        return False

def kruskal_algorithm(graph):
    edges = []
    for u in graph:
        for v, weight in graph[u].items():

            if u < v:
                edges.append((weight, u, v))

    edges.sort()

    vertices = list(graph.keys())
    dsu = DSU(vertices)

    mst = {vertex: [] for vertex in graph}
    min_weight = 0
    num_edges_in_mst = 0

    for weight, u, v in edges:
        if dsu.union(u, v):
            mst[u].append((v, weight))
            mst[v].append((u, weight))
            min_weight += weight
            num_edges_in_mst += 1
            if num_edges_in_mst == len(vertices) - 1:
                break

    return mst, min_weight

# %%
mst_kruskal, min_weight_kruskal = kruskal_algorithm(graph_2)
print("Minimum Spanning Tree for graph_2 (Kruskal):", mst_kruskal)
print("Minimum Weight for graph_2 (Kruskal):", min_weight_kruskal)
# Out:
# Minimum Spanning Tree for graph_2 (Kruskal): {'A': [('D', 5), ('B', 7)], 'B': [('A', 7), ('E', 7)], 'C': [('E', 5)], 'D': [('A', 5), ('F', 6)], 'E': [('C', 5), ('B', 7), ('G', 9)], 'F': [('D', 6)], 'G': [('E', 9)]}
# Minimum Weight for graph_2 (Kruskal): 39
